# %% [markdown]
# # Spatial Analysis of Demographic, Housing Prices and Public Transportation Accessibility in New York City

# %% [markdown]
# #### Yizhou Wang & Hongtao Huang
# #### Master of Regional Planning 25’

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://spatialityblog.com/save-money-living-10-minutes-away-from-subway/
